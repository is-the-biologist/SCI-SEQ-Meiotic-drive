# %% [markdown]
# # Seq Error simulation
#
# Short python notebook to test whether or not sequencing errors were incorportated correctly. Sequencing errors in simulated data will be "2" in my numpy array.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
seq = np.load("/home/iskander/Documents/Barbash_lab/mDrive/SIM_DATA/SPARSE_simData.npy", allow_pickle=True)

# %%
fig = plt.figure(figsize=(15,10))
axs = fig.subplots(5)
for arm in range(5):
    sns.scatterplot(seq[0][arm][:,0], seq[0][arm][:,1], ax=axs[arm])

# %% [markdown]
# It worked good work me
